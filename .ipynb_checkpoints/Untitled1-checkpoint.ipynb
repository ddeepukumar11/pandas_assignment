# %%
import pandas as pd

# %%
us_df= pd.read_csv('u.user',sep = '|')

# %%
us_df.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
us_df.gender
# Out:
# 0      M
# 1      F
# 2      M
# 3      M
# 4      F
# 5      M
# 6      M
# 7      M
# 8      M
# 9      M
# 10     F
# 11     F
# 12     M
# 13     M
# 14     F
# 15     M
# 16     M
# 17     F
# 18     M
# 19     F
# 20     M
# 21     M
# 22     F
# 23     F
# 24     M
# 25     M
# 26     F
# 27     M
# 28     M
# 29     M
#       ..
# 913    F
# 914    M
# 915    M
# 916    F
# 917    M
# 918    M
# 919    F
# 920    F
# 921    F
# 922    M
# 923    M
# 924    F
# 925    M
# 926    M
# 927    M
# 928    M
# 929    F
# 930    M
# 931    M
# 932    M
# 933    M
# 934    M
# 935    M
# 936    M
# 937    F
# 938    F
# 939    M
# 940    M
# 941    F
# 942    M
# Name: gender, Length: 943, dtype: object

# %%
us_df.gender.value_counts()
# Out:
# M    670
# F    273
# Name: gender, dtype: int64

# %%
drinks_df= pd.read_csv('drinks.csv')

# %%
drinks_df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks_df.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks_df.beer_servings.describe()
# Out:
# count    193.000000
# mean     106.160622
# std      101.143103
# min        0.000000
# 25%       20.000000
# 50%       76.000000
# 75%      188.000000
# max      376.000000
# Name: beer_servings, dtype: float64

# %%
us_df.occupation.value_counts()
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: occupation, dtype: int64

# %%
#multiple sort

# %%
us_df.sort_values(by=['age','gender'],ascending=False)
# Out:
#      user_id  age gender     occupation zip_code
# 480      481   73      M        retired    37771
# 766      767   70      M       engineer    00000
# 802      803   70      M  administrator    78212
# 859      860   70      F        retired    48322
# 558      559   69      M      executive    10022
# 584      585   69      M      librarian    98501
# 348      349   68      M        retired    61455
# 572      573   68      M        retired    48911
# 210      211   66      M       salesman    32605
# 317      318   65      M        retired    06518
# 563      564   65      M        retired    94591
# 650      651   65      M        retired    02903
# 422      423   64      M          other    91606
# 844      845   64      M         doctor    97405
# 363      364   63      M       engineer    01810
# 776      777   63      M     programmer    01810
# 857      858   63      M       educator    09645
# 519      520   62      M     healthcare    12603
# ...

# %%
young_bool = us_df[(us_df.age < 20) & (us_df.gender=='M')]

# %%
young_bool
# Out:
#      user_id  age gender     occupation zip_code
# 29        30    7      M        student    55436
# 56        57   16      M           none    84010
# 66        67   17      M        student    60402
# 67        68   19      M        student    22904
# 100      101   15      M        student    05146
# 109      110   19      M        student    77840
# 141      142   13      M          other    48118
# 178      179   15      M  entertainment    20755
# 220      221   19      M        student    20685
# 245      246   19      M        student    28734
# 256      257   17      M        student    77005
# 288      289   11      M           none    94619
# 290      291   19      M        student    44106
# 302      303   19      M        student    14853
# 319      320   19      M        student    24060
# 346      347   18      M        student    90210
# 366      367   17      M        student    37411
# 367      368   18      M        student    92113
# ...

# %%
#most freqent occupation for people having age > 60

# %%
occ = us_df[(us_df.age > 60)]

# %%
occ
# Out:
#      user_id  age gender     occupation zip_code
# 105      106   61      M        retired    55125
# 210      211   66      M       salesman    32605
# 265      266   62      F  administrator    78756
# 317      318   65      M        retired    06518
# 348      349   68      M        retired    61455
# 350      351   61      M       educator    49938
# 363      364   63      M       engineer    01810
# 422      423   64      M          other    91606
# 480      481   73      M        retired    37771
# 519      520   62      M     healthcare    12603
# 558      559   69      M      executive    10022
# 563      564   65      M        retired    94591
# 572      573   68      M        retired    48911
# 584      585   69      M      librarian    98501
# 650      651   65      M        retired    02903
# 766      767   70      M       engineer    00000
# 776      777   63      M     programmer    01810
# 802      803   70      M  administrator    78212
# ...

# %%
occ.occupation.value_counts()
# Out:
# retired          8
# engineer         3
# administrator    2
# educator         2
# librarian        1
# programmer       1
# executive        1
# doctor           1
# salesman         1
# other            1
# healthcare       1
# Name: occupation, dtype: int64

# %%
#10 countries have the highest total_litres_of_pure_alcohol

# %%
drinks_df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks_df.sort_values(by=['total_litres_of_pure_alcohol'],ascending=False)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 15              Belarus            142              373             42
# 98            Lithuania            343              244             56
# 3               Andorra            245              138            312
# 68              Grenada            199              438             28
# 45       Czech Republic            361              170            134
# 61               France            127              151            370
# 141  Russian Federation            247              326             73
# 81              Ireland            313              118            165
# 155            Slovakia            196              293            116
# 99           Luxembourg            236              133            271
# 65              Germany            346              117            175
# 75              Hungary            234              215            185
# ...

# %%
drinks_df.groupby('continent').mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
#Rename columns

# %%
drinks_df.rename(columns={'beer_servings':'beer','wine_servings':'wine'})
# Out:
#                   country  beer  spirit_servings  wine  \
# 0             Afghanistan     0                0     0
# 1                 Albania    89              132    54
# 2                 Algeria    25                0    14
# 3                 Andorra   245              138   312
# 4                  Angola   217               57    45
# 5       Antigua & Barbuda   102              128    45
# 6               Argentina   193               25   221
# 7                 Armenia    21              179    11
# 8               Australia   261               72   212
# 9                 Austria   279               75   191
# 10             Azerbaijan    21               46     5
# 11                Bahamas   122              176    51
# 12                Bahrain    42               63     7
# 13             Bangladesh     0                0     0
# 14               Barbados   143              173    36
# 15                Belarus   142              373    42
# ...

# %%
drinks_df['ml'] = drinks_df.total_litres_of_pure_alcohol * 1000

# %%
drinks_df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent       ml
# 0                           0.0        AS      0.0
# 1                           4.9        EU   4900.0
# 2                           0.7        AF    700.0
# 3                          12.4        EU  12400.0
# 4                           5.9        AF   5900.0

# %%
drinks_df.rename(columns={'total_litres_of_pure_alcohol':'litres'})
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
drinks_df['servings'] = drinks_df.beer_servings + drinks_df.spirit_servings + drinks_df.wine_servings

# %%
drinks_df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent       ml  servings
# 0                           0.0        AS      0.0         0
# 1                           4.9        EU   4900.0       275
# 2                           0.7        AF    700.0        39
# 3                          12.4        EU  12400.0       695
# 4                           5.9        AF   5900.0       319

# %%
#removing columns

# %%
drinks_df.drop('ml',axis= 1,inplace=True)

# %%
drinks_df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  servings
# 0                           0.0        AS         0
# 1                           4.9        EU       275
# 2                           0.7        AF        39
# 3                          12.4        EU       695
# 4                           5.9        AF       319

# %%
drinks_df[drinks_df.continent.isnull()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %%
drinks_df.isnull().sum(axis=0)
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# servings                         0
# dtype: int64

# %%
drinks_df.continent.value_counts(dropna=True)
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
drinks_df.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
#by default dropna is true

# %%
drinks_df.dropna()
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 0                 Afghanistan              0                0              0
# 1                     Albania             89              132             54
# 2                     Algeria             25                0             14
# 3                     Andorra            245              138            312
# 4                      Angola            217               57             45
# 6                   Argentina            193               25            221
# 7                     Armenia             21              179             11
# 8                   Australia            261               72            212
# 9                     Austria            279               75            191
# 10                 Azerbaijan             21               46              5
# 12                    Bahrain             42               63              7
# ...

# %%
ufo_df= pd.read_csv('ufo.csv')

# %%
ufo_df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo_df.shape
# Out:
# (80543, 5)

# %%
#four most frequent colors reported

# %%
ufo_df['Colors Reported'].value_counts()
# Out:
# ORANGE                          5216
# RED                             4809
# GREEN                           1897
# BLUE                            1855
# YELLOW                           842
# RED ORANGE                       486
# RED GREEN                        469
# RED BLUE                         445
# RED GREEN BLUE                   166
# GREEN BLUE                       147
# RED YELLOW                       146
# ORANGE YELLOW                    137
# ORANGE GREEN                      66
# ORANGE BLUE                       58
# YELLOW GREEN                      53
# RED YELLOW BLUE                   36
# RED YELLOW GREEN                  35
# RED ORANGE YELLOW                 32
# YELLOW BLUE                       27
# RED YELLOW GREEN BLUE             26
# RED ORANGE BLUE                   21
# YELLOW GREEN BLUE                 13
# ORANGE GREEN BLUE                 13
# RED ORANGE GREEN                  12
# RED ORANGE GREEN BLUE              8
# ...

# %%
#for reports in VA, whats the msot frequent city

# %%
ufo_df[ufo_df.State=='VA'].City.value_counts().head()
# Out:
# Virginia Beach    110
# Richmond           92
# Alexandria         48
# Roanoke            35
# Chesapeake         33
# Name: City, dtype: int64

# %%
ufo_df.iloc[10:20]
# Out:
#            City Colors Reported Shape Reported State             Time
# 10      Fontana             NaN          LIGHT    CA  8/15/1937 21:00
# 11     Waterloo             NaN       FIREBALL    AL   6/1/1939 20:00
# 12       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 13       Keokuk             NaN           OVAL    IA    7/7/1939 2:00
# 14    Ludington             NaN           DISK    MI   6/1/1941 13:00
# 15  Forest Home             NaN         CIRCLE    CA   7/2/1941 11:30
# 16  Los Angeles             NaN            NaN    CA   2/25/1942 0:00
# 17    Hapeville             NaN            NaN    GA   6/1/1942 22:30
# 18       Oneida             NaN      RECTANGLE    TN   7/15/1942 1:00
# 19   Bering Sea             RED          OTHER    AK  4/30/1943 23:00

# %%
ufo_df.loc[10:20,'City']
# Out:
# 10        Fontana
# 11       Waterloo
# 12         Belton
# 13         Keokuk
# 14      Ludington
# 15    Forest Home
# 16    Los Angeles
# 17      Hapeville
# 18         Oneida
# 19     Bering Sea
# 20       Nebraska
# Name: City, dtype: object

# %%
us_df.occupation.unique()
# Out:
# array(['technician', 'other', 'writer', 'executive', 'administrator',
#        'student', 'lawyer', 'educator', 'scientist', 'entertainment',
#        'programmer', 'librarian', 'homemaker', 'artist', 'engineer',
#        'marketing', 'none', 'healthcare', 'retired', 'salesman', 'doctor'],
#       dtype=object)

# %%
us_df['is_male'] = us_df.gender.map({'F':0,'M':1})

# %%
us_df.head()
# Out:
#    user_id  age gender  occupation zip_code  is_male
# 0        1   24      M  technician    85711        1
# 1        2   53      F       other    94043        0
# 2        3   23      M      writer    32067        1
# 3        4   24      M  technician    43537        1
# 4        5   33      F       other    15213        0

# %%
ufo_df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo_df['Time'] = pd.to_datetime(ufo_df.Time)

# %%
ufo_df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
ufo_df[ufo_df.Time > pd.datetime(2014,1,1)]
# Out:
#                    City Colors Reported Shape Reported State  \
# 75177       Clarksville          ORANGE         SPHERE    TN
# 75178         Henderson             NaN         SPHERE    NV
# 75179             Salem      RED YELLOW          LIGHT    OR
# 75180            Waxhaw             NaN           DISK    NC
# 75181           El Paso             NaN      FORMATION    TX
# 75182       Goose Creek           GREEN          LIGHT    SC
# 75183       Albuquerque             RED            EGG    NM
# 75184            Austin             NaN          LIGHT    TX
# 75185  Colorado Springs             NaN      FORMATION    CO
# 75186              Elon             NaN         CIRCLE    NC
# 75187      Mt. Pleasant             NaN         CIRCLE    SC
# 75188      Rohnert Park             RED         SPHERE    CA
# 75189    Spokane Valley             RED      FORMATION    WA
# 75190      Jacksonville          ORANGE         CIRCLE    FL
# ...
